# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
energydata = pd.read_excel("En_In.xls")
energydata = energydata.drop(range(234, 282))
energydata = energydata.drop(range(17))
energydata = energydata.drop(columns=["Unnamed: 0", "Unnamed: 1"])
energydata.columns = ["Country", "Energy Supply", "Energy Supply per Capita", "% Renewable"]
energydata = energydata.replace(["..."], np.NaN)
energydata
# Out:
#                                                Country  Energy Supply  \
# 17                                         Afghanistan          321.0
# 18                                             Albania          102.0
# 19                                             Algeria         1959.0
# 20                                      American Samoa            NaN
# 21                                             Andorra            9.0
# ..                                                 ...            ...
# 229                                          Ukraine18         4844.0
# 230                               United Arab Emirates         2710.0
# 231  United Kingdom of Great Britain and Northern I...         7920.0
# 232                        United Republic of Tanzania          994.0
# 233                         United States of America20        90838.0
#
#      Energy Supply per Capita  % Renewable
# 17                       10.0    78.669280
# ...

# %%
energydata["Energy Supply"] = energydata["Energy Supply"] * 1_000_000
energydata
# Out:
#                                                Country  Energy Supply  \
# 17                                         Afghanistan   3.210000e+08
# 18                                             Albania   1.020000e+08
# 19                                             Algeria   1.959000e+09
# 20                                      American Samoa            NaN
# 21                                             Andorra   9.000000e+06
# ..                                                 ...            ...
# 229                                          Ukraine18   4.844000e+09
# 230                               United Arab Emirates   2.710000e+09
# 231  United Kingdom of Great Britain and Northern I...   7.920000e+09
# 232                        United Republic of Tanzania   9.940000e+08
# 233                         United States of America20   9.083800e+10
#
#      Energy Supply per Capita  % Renewable
# 17                       10.0    78.669280
# ...

# %%
energydata["Country"] = energydata["Country"].replace(["Republic of Korea"], "South Korea")
energydata["Country"] = energydata["Country"].replace(["United States of America"], "United states")
energydata["Country"] = energydata["Country"].replace(["United Kingdom of Great Britain and Northern Ireland"], "United kingdom")
energydata["Country"] = energydata["Country"].replace(["China, Hong Kong Special Administrative Region"], "Hong Kong")

def correct_country_name(s):
    res = []
    for e in s:
        if e.isdigit():
            continue
        elif e == "(":
            break
        else:
            res.append(e)
    return "".join(res).rstrip()

energydata["Country"] = energydata["Country"].apply(lambda x: correct_country_name(x))
energydata.loc[energydata["Country"].isin(["American Samoa", "South Korea", "Bolivia"])]
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 20   American Samoa            NaN                       NaN     0.641026
# 41          Bolivia   3.360000e+08                      32.0    31.477120
# 181     South Korea   1.100700e+10                     221.0     2.279353

# %%
GDP = pd.read_csv("gpd.csv")
headers = list(GDP.loc[3])
headers[0] = "Country"
for i in range(4, len(headers)):
    headers[i] = int(headers[i])
GDP.columns = headers
GDP = GDP.drop([0, 1, 2, 3])
GDP["Country"] = GDP["Country"].replace(["Korea, Rep."], "South Korea")
GDP["Country"] = GDP["Country"].replace(["Iran, Islamic Rep."], "Iran")
GDP["Country"] = GDP["Country"].replace(["Hong Kong SAR, China"], "Hong Kong")

GDP
# Out:
#               Country Country Code                            Indicator Name  \
# 4               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 5             Andorra          AND  GDP at market prices (constant 2010 US$)
# 6         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 7              Angola          AGO  GDP at market prices (constant 2010 US$)
# 8             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 263       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 264      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 265  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 266            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 267          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
GDP.head(1)
# Out:
#   Country Country Code                            Indicator Name  \
# 4   Aruba          ABW  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...  2006  2007  2008  \
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#    2009          2010  2011  2012  2013  2014  2015
# 4   NaN  2.467704e+09   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 60 columns]

# %%
GDP[GDP["Country"] == "South Korea"]
# Out:
#          Country Country Code                            Indicator Name  \
# 127  South Korea          KOR  GDP at market prices (constant 2010 US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 127  NY.GDP.MKTP.KD  2.757696e+10  2.893825e+10  2.964966e+10  3.247578e+10
#
#              1964          1965  ...          2006          2007  \
# 127  3.493136e+10  3.674434e+10  ...  9.410199e+11  9.924316e+11
#
#              2008          2009          2010          2011          2012  \
# 127  1.020510e+12  1.027730e+12  1.094499e+12  1.134796e+12  1.160809e+12
#
#              2013          2014          2015
# 127  1.194429e+12  1.234340e+12  1.266580e+12
#
# [1 rows x 60 columns]

# %%
Scimagojr = pd.read_excel("scimagojr.xlsx")
Dataset = pd.merge(Scimagojr, energydata, how="left", on="Country")
Dataset = pd.merge(Dataset, GDP, how="left", on="Country")

Dataset = Dataset.set_index("Country")
Dataset = Dataset.astype({"Rank": int})
Dataset = Dataset.drop(columns=[x for x in range(1960, 2006)])
Dataset = Dataset.drop(columns=["Country Code", "Indicator Code", "Indicator Name"])
Dataset.columns
# Out:
# Index([                    'Rank',                'Documents',
#               'Citable documents',                'Citations',
#                  'Self-citations',   'Citations per document',
#                         'H index',            'Energy Supply',
#        'Energy Supply per Capita',              '% Renewable',
#                              2006,                       2007,
#                              2008,                       2009,
#                              2010,                       2011,
#                              2012,                       2013,
#                              2014,                       2015],
#       dtype='object')

# %%
Result = Dataset[:15]
Result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
Result.shape
# Out:
# (15, 20)

# %%
def task_eight():
    years = [x for x in range(2006, 2016)]
    return Result[years].mean(axis=1, skipna=True).sort_values(ascending=False)[:15]

# %%
 task_eight()
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
def task_nine():
    return "France", Result.loc["France"][2015] - Result.loc["France"][2006]

# %%
task_nine()
# Out:
# ('France', 153345695364.24023)

# %%
def task_ten():
    res = list(Result.sort_values("% Renewable", ascending=False).index.values)[0]
    return res, Result.loc[res]["% Renewable"]

# %%
task_ten()
# Out:
# ('Brazil', 69.64803)

# %%
def task_eleven():
    Result.loc["Population"] = Result["Energy Supply"] / Result["Energy Supply per Capita"]
    res = list(Result["Population"].sort_values(ascending=False).index.values)[4]
    return res, Result.loc[res]["Population"]

# %%
task_eleven()
# Out:
# c:\users\admin\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\admin\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
def task_twelve():
    Result["CitPerCap"] = Result["Citable documents"] / Result["Population"]
    return Result["Energy Supply per Capita"].corr(Result['CitPerCap'], method="pearson")

# %%
task_twelve()

# %%
def task_thirteen():
    temp = Result["% Renewable"].median(axis=0)
    Result["renew"] = Result.apply(lambda x: 1 if x["% Renewable"] > temp else 0, axis=1)
    Result.sort_values(by='Rank')
    return Result["renew"]

# %%
task_thirteen()

# %%
def task_forteen():
    ContinentDict = {'China': 'Asia',
                     'United States': 'North America',
                     'Japan': 'Asia',
                     'United Kingdom': 'Europe',
                     'Russian Federation': 'Europe',
                     'Canada': 'North America',
                     'Germany': 'Europe',
                     'India': 'Asia',
                     'France': 'Europe',
                     'South Korea': 'Asia',
                     'Italy': 'Europe',
                     'Spain': 'Europe',
                     'Iran': 'Asia',
                     'Australia': 'Australia',
                     'Brazil': 'South America'}
    temp = pd.DataFrame(columns=['size', 'sum', 'mean', 'std'])
    Result['Population'] = Result['Energy Supply'] / Result['Energy Supply per Capita']
    for elem, val in Result.groupby(ContinentDict):
        temp.loc[elem] = [len(val), val['Population'].sum(), val['Population'].mean(), val['Population'].std()]
    temp = temp.astype({"size": int})
    return temp

# %%
task_forteen()

# %%
def task15():
    ContinentDict  = {'China':['Asia', "yellow"],
                  'United States':['North America', "red"],
                  'Japan':['Asia', "yellow"], 
                  'United Kingdom':['Europe', "blue"],
                  'Russian Federation':['Europe', "blue"],
                  'Canada':['North America', "red"],
                  'Germany':['Europe', "blue"],
                  'India':['Asia', "yellow"],
                  'France':['Europe', "blue"],
                  'South Korea':['Asia', "yellow"], 
                  'Italy':['Europe', "blue"],
                  'Spain':['Europe', "blue"],
                  'Iran':['Asia', "yellow"],
                  'Australia':['Australia', "green"],
                  'Brazil':['South America', "cyan"]}
    
    x, y, z = df["Rank"], df["% Renewable"], list(df.index.values)
    for i, text in enumerate(list(df.index)):
        plt.annotate(text, (x[i] - 0.3, y[i]))
    for elem in z:
        plt.scatter(x=x.loc[elem], y=y.loc[elem], s=df[2015][elem]/10_000_000_000*8, alpha = 0.4, c = ContinentDict[elem][1])
    plt.xticks([i for i in range(0, len(list(df.index))+1)])
    plt.gcf().set_size_inches((15, 5))  
    plt.show()
